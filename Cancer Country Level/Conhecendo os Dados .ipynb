# %%
import pandas as pd
dados = pd.read_csv('death .csv')

# %%
dados.head()
# Out:
#    index                       County   FIPS Met Objective of 45.5? (1)  \
# 0      0                United States      0                         No
# 1      1       Perry County, Kentucky  21193                         No
# 2      2      Powell County, Kentucky  21197                         No
# 3      3  North Slope Borough, Alaska   2185                         No
# 4      4      Owsley County, Kentucky  21189                         No
#
#   Age-Adjusted Death Rate Lower 95% Confidence Interval for Death Rate  \
# 0                      46                                         45.9
# 1                   125.6                                        108.9
# 2                   125.3                                        100.2
# 3                   124.9                                           73
# 4                   118.5                                         83.1
#
#   Upper 95% Confidence Interval for Death Rate Average Deaths per Year  \
# ...

# %%
# Não há necessidade de ter 2 index, por isso, vamos apagar o que veio com o DataFrame e manter o do Jupyter
dados.drop(['index'], axis = 1, inplace = True)

# %%
dados.head()
# Out:
#                         County   FIPS Met Objective of 45.5? (1)  \
# 0                United States      0                         No
# 1       Perry County, Kentucky  21193                         No
# 2      Powell County, Kentucky  21197                         No
# 3  North Slope Borough, Alaska   2185                         No
# 4      Owsley County, Kentucky  21189                         No
#
#   Age-Adjusted Death Rate Lower 95% Confidence Interval for Death Rate  \
# 0                      46                                         45.9
# 1                   125.6                                        108.9
# 2                   125.3                                        100.2
# 3                   124.9                                           73
# 4                   118.5                                         83.1
#
#   Upper 95% Confidence Interval for Death Rate Average Deaths per Year  \
# 0                                         46.1                 157,376
# ...

# %%
dados.rename(columns = {'County' : 'Condado', 'FIPS' : 'Código Federal', 'Met Objective of 45.5? (1)' : 'Objetivo Taxa Mortalidade (45,5)', 'Age-Adjusted Death Rate' : 'Taxa Mortalidade por Idade', 'Average Deaths per Year' : 'Média de Mortes/Ano', 'Recent Trend (2)' : 'Tendência Recente', 'Recent 5-Year Trend (2) in Death Rates' : 'Tendência recente taxas de mortalidade (5 anos)'}, inplace = True)

# %%
dados.head()
# Out:
#                        Condado  Código Federal  \
# 0                United States               0
# 1       Perry County, Kentucky           21193
# 2      Powell County, Kentucky           21197
# 3  North Slope Borough, Alaska            2185
# 4      Owsley County, Kentucky           21189
#
#   Objetivo Taxa Mortalidade (45,5) Taxa Mortalidade por Idade  \
# 0                               No                         46
# 1                               No                      125.6
# 2                               No                      125.3
# 3                               No                      124.9
# 4                               No                      118.5
#
#   Lower 95% Confidence Interval for Death Rate  \
# 0                                         45.9
# 1                                        108.9
# 2                                        100.2
# 3                                           73
# 4                                         83.1
#
# ...

# %%
dados.drop(['Lower 95% Confidence Interval for Death Rate', 'Upper 95% Confidence Interval for Death Rate', 'Lower 95% Confidence Interval for Trend', 'Upper 95% Confidence Interval for Trend'], axis = 1, inplace = True)

# %%
dados.head()
# Out:
#                        Condado  Código Federal  \
# 0                United States               0
# 1       Perry County, Kentucky           21193
# 2      Powell County, Kentucky           21197
# 3  North Slope Borough, Alaska            2185
# 4      Owsley County, Kentucky           21189
#
#   Objetivo Taxa Mortalidade (45,5) Taxa Mortalidade por Idade  \
# 0                               No                         46
# 1                               No                      125.6
# 2                               No                      125.3
# 3                               No                      124.9
# 4                               No                      118.5
#
#   Média de Mortes/Ano Tendência Recente  \
# 0             157,376           falling
# 1                  43            stable
# 2                  18            stable
# 3                   5                **
# 4                   8            stable
#
#   Tendência recente taxas de mortalidade (5 anos)
# ...

# %%
dados.shape
# Out:
# (3141, 7)

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3141 entries, 0 to 3140
# Data columns (total 7 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Condado                                          3141 non-null   object
#  1   Código Federal                                   3141 non-null   int64
#  2   Objetivo Taxa Mortalidade (45,5)                 3141 non-null   object
#  3   Taxa Mortalidade por Idade                       3141 non-null   object
#  4   Média de Mortes/Ano                              3141 non-null   object
#  5   Tendência Recente                                3141 non-null   object
#  6   Tendência recente taxas de mortalidade (5 anos)  3141 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 171.9+ KB

# %%
dados['Condado'].unique()
# Out:
# array(['United States', 'Perry County, Kentucky',
#        'Powell County, Kentucky', ..., 'Zapata County, Texas',
#        'Zavala County, Texas', 'Ziebach County, South Dakota'],
#       dtype=object)

# %%
dados['Condado'].value_counts()
# Out:
# United States                   1
# Powell County, Montana          1
# Tillamook County, Oregon        1
# Aiken County, South Carolina    1
# Union County, South Dakota      1
#                                ..
# Upson County, Georgia           1
# Towns County, Georgia           1
# La Salle County, Illinois       1
# Union County, Iowa              1
# Ziebach County, South Dakota    1
# Name: Condado, Length: 3141, dtype: int64

# %%
dados['Código Federal'].unique()
# Out:
# array([    0, 21193, 21197, ..., 48505, 48507, 46137], dtype=int64)

# %%
dados['Código Federal'].value_counts()
# Out:
# 0        1
# 30077    1
# 41057    1
# 45003    1
# 46127    1
#         ..
# 13293    1
# 13281    1
# 17099    1
# 19175    1
# 46137    1
# Name: Código Federal, Length: 3141, dtype: int64

# %%
dados['Objetivo Taxa Mortalidade (45,5)'].unique()
# Out:
# array(['No', 'Yes', '*'], dtype=object)

# %%
dados['Objetivo Taxa Mortalidade (45,5)'].value_counts()
# Out:
# No     1985
# Yes     828
# *       328
# Name: Objetivo Taxa Mortalidade (45,5), dtype: int64

# %%
selecao = dados['Objetivo Taxa Mortalidade (45,5)'] == '*'
dados[selecao]
# Out:
#                                              Condado  Código Federal  \
# 2813                             Adams County, Idaho           16003
# 2814                              Adams County, Iowa           19003
# 2815                      Adams County, North Dakota           38001
# 2816      Aleutians East Borough, Alaska<sup>3</sup>            2013
# 2817  Aleutians West Census Area, Alaska<sup>3</sup>            2016
# ...                                              ...             ...
# 3136    Yakutat City and Borough, Alaska<sup>3</sup>            2282
# 3137               Yukon-Koyukuk Census Area, Alaska            2290
# 3138                            Zapata County, Texas           48505
# 3139                            Zavala County, Texas           48507
# 3140                    Ziebach County, South Dakota           46137
#
#      Objetivo Taxa Mortalidade (45,5) Taxa Mortalidade por Idade  \
# 2813                                *                          *
# ...

# %%
dados['Taxa Mortalidade por Idade'].unique()
# Out:
# array(['46', '125.6', '125.3', '124.9', '118.5', '113.5', '111.1',
#        '110.3', '109.1', '106', '104.6', '103.5', '103.3', '98.7', '98.5',
#        '97.2', '96.5', '96.1', '95.6', '95.3', '95.1', '94.9', '94.6',
#        '92.7', '92.5', '92.3', '91.9', '90.8', '90.5', '90.2', '89.6',
#        '89.3', '89.2', '89.1', '89', '88.9', '88', '87.9', '87.4', '87.2',
#        '87', '86.8', '86.6', '85.9', '85.4', '85.1', '84.8', '84.5',
#        '84.3', '84.2', '84.1', '84', '83.8', '83.6', '83.5', '83.1', '83',
#        '82.7', '82.3', '82', '81.9', '81.7', '81.6', '81.5', '81.4',
#        '81.3', '81.2', '81.1', '81', '80.8', '80.6', '80.5', '80.3',
#        '80.2', '80.1', '80', '79.9', '79.8', '79.6', '79.5', '79.3',
#        '79.1', '79', '78.8', '78.7', '78.5', '78.4', '78.3', '78.2',
#        '78.1', '78', '77.8', '77.7', '77.6', '77.5', '77.4', '77.3',
#        '76.9', '76.8', '76.7', '76.6', '76.4', '76.3', '76.2', '76.1',
# ...

# %%
dados['Taxa Mortalidade por Idade'].value_counts()
# Out:
# *        328
# 48.3      19
# 51.8      17
# 56.3      15
# 54.4      14
#         ...
# 74.9       1
# 95.6       1
# 95.3       1
# 74.8       1
# 109.1      1
# Name: Taxa Mortalidade por Idade, Length: 618, dtype: int64

# %%
selecao = dados['Taxa Mortalidade por Idade'] == '*'
dados[selecao]
# Out:
#                                              Condado  Código Federal  \
# 2813                             Adams County, Idaho           16003
# 2814                              Adams County, Iowa           19003
# 2815                      Adams County, North Dakota           38001
# 2816      Aleutians East Borough, Alaska<sup>3</sup>            2013
# 2817  Aleutians West Census Area, Alaska<sup>3</sup>            2016
# ...                                              ...             ...
# 3136    Yakutat City and Borough, Alaska<sup>3</sup>            2282
# 3137               Yukon-Koyukuk Census Area, Alaska            2290
# 3138                            Zapata County, Texas           48505
# 3139                            Zavala County, Texas           48507
# 3140                    Ziebach County, South Dakota           46137
#
#      Objetivo Taxa Mortalidade (45,5) Taxa Mortalidade por Idade  \
# 2813                                *                          *
# ...

# %%
a = dados.shape[0]

# %%
a
# Out:
# 3141

# %%
b = dados[selecao].shape[0]
b
# Out:
# 328

# %%
a - b
# Out:
# 2813

# %%
dados_new = dados[~selecao]

# %%
dados_new.shape[0]
# Out:
# 2813

# %%
dados_new
# Out:
#                           Condado  Código Federal  \
# 0                   United States               0
# 1          Perry County, Kentucky           21193
# 2         Powell County, Kentucky           21197
# 3     North Slope Borough, Alaska            2185
# 4         Owsley County, Kentucky           21189
# ...                           ...             ...
# 2808       Eagle County, Colorado            8037
# 2809          Summit County, Utah           49043
# 2810            Utah County, Utah           49049
# 2811  McKinley County, New Mexico           35031
# 2812           Cache County, Utah           49005
#
#      Objetivo Taxa Mortalidade (45,5) Taxa Mortalidade por Idade  \
# 0                                  No                         46
# 1                                  No                      125.6
# 2                                  No                      125.3
# 3                                  No                      124.9
# ...

# %%
dados_new.index = range(dados_new.shape[0])

# %%
dados_new
# Out:
#                           Condado  Código Federal  \
# 0                   United States               0
# 1          Perry County, Kentucky           21193
# 2         Powell County, Kentucky           21197
# 3     North Slope Borough, Alaska            2185
# 4         Owsley County, Kentucky           21189
# ...                           ...             ...
# 2808       Eagle County, Colorado            8037
# 2809          Summit County, Utah           49043
# 2810            Utah County, Utah           49049
# 2811  McKinley County, New Mexico           35031
# 2812           Cache County, Utah           49005
#
#      Objetivo Taxa Mortalidade (45,5) Taxa Mortalidade por Idade  \
# 0                                  No                         46
# 1                                  No                      125.6
# 2                                  No                      125.3
# 3                                  No                      124.9
# ...

# %%
dados_new.to_csv('dados_death.csv', index = False)
